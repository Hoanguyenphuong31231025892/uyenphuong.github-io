# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoanguyenphuong31231025892/uyenphuong.github-io/blob/main/ex2_scientific1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import thư viện**

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# **Sinh ngẫu nhiên hình tròn**

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.01, 1.00]: 10 samples [[0.75413361 0.29922871 0.72451206 0.92585978 0.27825689 0.87381527
#  0.96599517 0.61856444 0.83930281 0.85584692]]
# + y: len=50, [0.01, 0.96]: 10 samples [[0.446716   0.82350355 0.57209371 0.59141169 0.88811898 0.06597258
#  0.58936279 0.07504957 0.71908836 0.37830803]]
# + colors: len=50, [0.01, 0.99]: 10 samples [[0.73754901 0.0696829  0.58772245 0.97322799 0.43047665 0.00777623
#  0.84695175 0.88295604 0.98865597 0.45975749]]
# + area: len=50, [0.47, 687.01]: 10 samples [[639.48101029   5.35070993 158.3497416   35.72620699 102.14704728
#  459.14985235  36.29511853 215.98670516  26.58939247  29.20258491]]

# %% [markdown]
# **Hiển thị đồ thị**

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# **Kết** **thúc**
